# %% [markdown]
# ### Testing file

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import pandas as pd

import os,sys
# sys.addaudithook
rpath = os.getcwd()
sys.path.insert(0,"../")
# import utils

import dimred ### library of dimension reduction
from dimred.flowpipe import Elbow2,ServicePIpe
from dimred.flowcistern import Knob2,interactive,IntSlider,interact_manual

from dimred.data.loader import LoadMPI, LoadOne,datapath__,LoadNumpy
from dimred.data.preprocess import AvgMaxScalar, MinMaxScalar, Shaper, MaxAvgScalar

# %% [markdown]
# ### Data description

# %%
from tqdm import tqdm
import time
n = 5
m = 300
# with tqdm(total=n * m) as pbar:
for i1 in tqdm(range(n),position=0):
    for i2 in tqdm(range(m),leave=False,position=1):
        # do something, e.g. sleep
        time.sleep(0.01)
                # pbar.update(1)
# Out:
# 100%|██████████| 5/5 [00:15<00:00,  3.08s/it]

# %%
from tqdm.notebook import tqdm_notebook as tqdm

for i in tqdm(range(10**3)):
    for j in tqdm(range(100)):
        x = np.random.randn(100)
# Out:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Exception ignored in: <function tqdm.__del__ at 0x7efd7c232700>
# Traceback (most recent call last):
#   File "/home/shubham/anaconda3/envs/cantera/lib/python3.9/site-packages/tqdm/std.py", line 1146, in __del__
#     def __del__(self):
# KeyboardInterrupt:
# ...
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
data_list = ["hcci10","hcci20","hcci50","hcci90","hcci40","onedsin","onedcos"]

def f(select_data):
    global rn,dat
    dat = LoadNumpy(data_name=select_data[:4],file_name=select_data)
    rn = Elbow2(dat)
    print(f"selected dataset {select_data}")
interact_manual(f,select_data=data_list)
# Out:
# interactive(children=(Dropdown(description='select_data', options=('hcci10', 'hcci20', 'hcci50', 'hcci90', 'hc…
# <function __main__.f(select_data)>

# %%
interactive(dat.plotImg,species=dat.varid)
# Out:
# interactive(children=(Dropdown(description='species', options={'H': 0, 'H2': 1, 'O': 2, 'O2': 3, 'OH': 4, 'H2O…

# %% [markdown]
# ### Dimensional analysis

# %%
import numpy as np
import numba

x = np.random.randn(425*50,30)

# %%
from dimred.models.linear.moments import co_kurtosis,co_variance,val_kurtosis,ex_kurtosis

# %%
ck1 =co_kurtosis(x)
# Out:
# 100%|██████████| 21250/21250 [00:30<00:00, 685.94it/s]

# %%
ck2 = val_kurtosis(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2730263/560109380.py in <module>
# ----> 1 ck2 = val_kurtosis(x)
#
# NameError: name 'val_kurtosis' is not defined

# %%
# %%time
ck3 = ex_kurtosis(x)
# Out:
# CPU times: user 45.9 s, sys: 67.1 ms, total: 46 s
# Wall time: 45.9 s

# %%
# %%time
ck33 = ex_kurtosis(x)

# %%
np.sum(abs(ck1-ck3))
# Out:
# 4633.33819470982

# %%
np.sum(abs(ck2-ck3))
# Out:
# 2.208573512874032e-11

# %%
topbar = Knob2(rn)

# %%
topbar
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2730263/1410525480.py in <module>
# ----> 1 topbar
#
# NameError: name 'topbar' is not defined

# %%
# Out:
# 100%|██████████| 448896/448896 [00:02<00:00, 198281.20it/s]
